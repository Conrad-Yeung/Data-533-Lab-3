# %%
import unittest
from accounting_chequingtest import Testchequing
from accounting_savingtest import Testsaving

# %%
def my_suite():
    suite = unittest.TestSuite()
    result = unittest.TestResult()
    suite.addTest(unittest.makeSuite(Testchequing))
    suite.addTest(unittest.makeSuite(Testsaving))
    runner = unittest.TextTestRunner()
    print(runner.run(suite))

# %%
my_suite()
# Out:
# .........
# Class created
# 	Start Test
# Testing chequing.deposit
# $1000.52 has been deposited to account 55367482.
# Current balance: $2500.52.
#
# $100.00 has been deposited to account 60537153.
# Current balance: $2100.00.
#
# Amount to deposit must be greater than 0.
#
# Amount to deposit must be greater than 0.
#
# 	Test Complete
#
# 	Start Test
# Testing chequing.withdraw
# $569.00 has been withdrawn from account 55367482.
# Current balance: $1931.52.
#
# $29.90 has been withdrawn from account 60537153.
# Current balance: $2070.10.
#
# Amount to withdraw must be greater than 0.
#
# Amount to withdraw must be greater than 0.
#
# Your current transaction limit is $1000.00, therefore you are unable to withdraw the requested amount of $1500.10.
#
# Your current transaction limit is $3000.00, therefore you are unable to withdraw the requested amount of $3001.00.
#
# 	Test Complete
#
# 	Start Test
# Testing chequing.change_lim
# Your transaction limit has increased from $1000.00 to $1400.00.
#
# Your transaction limit has decreased from $3000.00 to $20.00.
#
# $1400.00 has been withdrawn from account 55367482.
# Current balance: $531.52.
#
# Your current transaction limit is $20.00, therefore you are unable to withdraw the requested amount of $21.00.
#
# Account limit must be greater than 0.
#
# 	Test Complete
#
# 	Start Test
# Testing chequing.bal_hist and .bal_time
# 	Test Complete
#
# Class torn down
# #################
# Class created
# 	Start Test
# Testing saving.deposit
# $102.69 has been deposited to account 96740041.
# Current balance: $102.69.
#
# $1500.00 has been deposited to account 47239608.
# Current balance: $1500.00.
#
# Amount to deposit must be greater than 0.
#
# Amount to deposit must be greater than 0.
#
# 	Test Complete
#
# 	Start Test
# Testing saving.withdraw
# $69.00 has been withdrawn from account 96740041.
# Current balance: $33.69.
#
# $29.90 has been withdrawn from account 47239608.
# Current balance: $1470.10.
#
# Amount to withdraw must be greater than 0.
#
# Amount to withdraw must be greater than 0.
#
# Your current transaction limit is $1000.00, therefore you are unable to withdraw the requested amount of $1500.10.
#
# Your current transaction limit is $1500.00, therefore you are unable to withdraw the requested amount of $3001.00.
#
# 	Test Complete
#
# 	Start Test
# Testing saving.change_lim
# Your transaction limit has decreased from $1000.00 to $500.00.
#
# Your transaction limit has increased from $1500.00 to $2000.00.
#
# $0.69 has been withdrawn from account 96740041.
# Current balance: $33.00.
#
# $21.00 has been withdrawn from account 47239608.
# Current balance: $1449.10.
#
# Account limit must be greater than 0.
#
# 	Test Complete
#
# 	Start Test
# Testing saving.setfixdeposit
# Your deposit of $1000.00 has been fixed for a year with an interest rate of 1.00%.
# On 2021/12/03, $1010.0 will be added to your Savings account.
#
# Your deposit of $500.00 has been fixed for a year with an interest rate of 50.00%.
# On 2021/12/03, $750.0 will be added to your Savings account.
#
# You already have a fixed deposit in process. The current amount locked in is $1000.00 at a rate of 1.00%. The amount will be made available on 2021/12/03.
#
# You already have a fixed deposit in process. The current amount locked in is $500.00 at a rate of 50.00%. The amount will be made available on 2021/12/03.
#
# Your fixed depot created on 2020/12/03 is complete.
#
# $1010.00 has been deposited to account 96740041.
# Current balance: $1043.00.
#
# Your fixed depot created on 2020/12/03 is complete.
#
# $750.00 has been deposited to account 47239608.
# Current balance: $2199.10.
#
# 	Test Complete
#
# 	Start Test
# Testing saving.bal_hist and .bal_time
# 	Test Complete
#
# Class torn down
# <unittest.runner.TextTestResult run=9 errors=0 failures=0>
# ----------------------------------------------------------------------
# Ran 9 tests in 0.025s
#
# OK
